# %%
# --- Imports ---
import datetime as dt
import math
import os
import re
import sys
import time
import warnings
import json
import functools
from pathlib import Path

# Data Manipulation
import numpy as np
import pandas as pd

# Validation
from pydantic import BaseModel, Field, ValidationError

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display, Latex, Math

# Console Formatting
from colorama import Fore, Style

# Logging
from loguru import logger
import uuid

# Secrets Management
sys.path.append("/mnt/git/github/gabemcwilliams/common-components/security")
from vault_mgr import *

# API & Scraping Utilities
import requests
from requests.adapters import HTTPAdapter, Retry
from urllib.parse import urlparse, urlencode
import certifi
from bs4 import BeautifulSoup
from PIL import Image
from io import BytesIO

# %%
# Image storage directory
images_dir = '/mnt/mls/images'

# %%
vault = VaultManager(debug=True)
secrets = vault.read_secret(mount_point='api', path='pexels')
# Out:
# =========== Vault Environment Diagnostics ===========
#
# VAULT_ADDR         : [CONFIGURED]
# VAULT_CLIENT_CERT  : [CONFIGURED]
# VAULT_CLIENT_KEY   : [CONFIGURED]
# VAULT_CACERT       : [CONFIGURED]
# SSL_CERT_FILE      : [CONFIGURED]
#
# =====================================================
#
# Cert Preview: public.crt found
# Key Preview: private.key found
#  * Vault Client is [AUTHENTICATED]

# %%
def api_call(query_label: str | None = None, page_no: str | None = None, per_page: int = 80) -> dict:
    """
    Calls the Pexels API to retrieve image search results.

    Args:
        query_label (str | None): Search keyword (e.g., "plant").
        page_no (str | None): Page number of results to retrieve.
        per_page (int): Number of images per page (default is 80).

    Returns:
        dict: Parsed JSON response from the Pexels API containing metadata and image URLs.
    """

    headers = {'Authorization': secrets['api_key']}
    params = {"query": query_label, "per_page": per_page, "page": page_no}
    request_url = f'{secrets["base_uri"]}/v1/search'
    print(request_url)
    response = requests.get(request_url, verify=certifi.where(), headers=headers, params=params)
    return response.json()

# %%
from pathlib import Path

query_list = [
    "leaf veins macro",
    "succulent cluster",
    "tropical foliage pattern",
    "jungle canopy plant",
    "young sprout macro"
]

output_dir = Path("/mnt/mls/data/pexels_metadata")
output_dir.mkdir(parents=True, exist_ok=True)

for query_label in query_list:
    print(f"\n--- Starting query: '{query_label}' ---\n")
    page = 0
    max_pages = 80
    all_pages = []

    parquet_path = output_dir / f"{query_label.replace(' ', '_')}.parquet"

    while page < max_pages:
        page += 1
        try:
            c_dict = api_call(query_label=query_label, page_no=page)
            print(f"  Fetched Page {c_dict['page']} of {query_label}")
            df_current = pd.DataFrame(c_dict['photos'])

            if df_current.empty:
                print("  Empty page — stopping early.")
                break

            df_current['query'] = query_label
            df_current['page'] = page

            all_pages.append(df_current)

            # Save progress
            pd.concat(all_pages, ignore_index=True).to_parquet(parquet_path, index=False)
            print(f"  Saved page {page} to {parquet_path}")

        except Exception as e:
            print(f"  [ERROR] Failed on page {page} of '{query_label}': {e}")
            break

    print(f"--- Finished '{query_label}' with {page} pages ---\n")
# Out:
# --- Starting query: 'leaf veins macro' ---
#
# https://api.pexels.com/v1/search
#   Fetched Page 1 of leaf veins macro
#   Saved page 1 to /mnt/mls/data/pexels_metadata/leaf_veins_macro.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 2 of leaf veins macro
#   Saved page 2 to /mnt/mls/data/pexels_metadata/leaf_veins_macro.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 3 of leaf veins macro
#   Saved page 3 to /mnt/mls/data/pexels_metadata/leaf_veins_macro.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 4 of leaf veins macro
#   Saved page 4 to /mnt/mls/data/pexels_metadata/leaf_veins_macro.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 5 of leaf veins macro
#   Saved page 5 to /mnt/mls/data/pexels_metadata/leaf_veins_macro.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 6 of leaf veins macro
#   Saved page 6 to /mnt/mls/data/pexels_metadata/leaf_veins_macro.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 7 of leaf veins macro
#   Saved page 7 to /mnt/mls/data/pexels_metadata/leaf_veins_macro.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 8 of leaf veins macro
#   Saved page 8 to /mnt/mls/data/pexels_metadata/leaf_veins_macro.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 9 of leaf veins macro
#   Saved page 9 to /mnt/mls/data/pexels_metadata/leaf_veins_macro.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 10 of leaf veins macro
#   Saved page 10 to /mnt/mls/data/pexels_metadata/leaf_veins_macro.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 11 of leaf veins macro
#   Saved page 11 to /mnt/mls/data/pexels_metadata/leaf_veins_macro.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 12 of leaf veins macro
#   Saved page 12 to /mnt/mls/data/pexels_metadata/leaf_veins_macro.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 13 of leaf veins macro
#   Saved page 13 to /mnt/mls/data/pexels_metadata/leaf_veins_macro.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 14 of leaf veins macro
#   Saved page 14 to /mnt/mls/data/pexels_metadata/leaf_veins_macro.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 15 of leaf veins macro
#   Saved page 15 to /mnt/mls/data/pexels_metadata/leaf_veins_macro.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 16 of leaf veins macro
#   Saved page 16 to /mnt/mls/data/pexels_metadata/leaf_veins_macro.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 17 of leaf veins macro
#   Saved page 17 to /mnt/mls/data/pexels_metadata/leaf_veins_macro.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 18 of leaf veins macro
#   Saved page 18 to /mnt/mls/data/pexels_metadata/leaf_veins_macro.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 19 of leaf veins macro
#   Saved page 19 to /mnt/mls/data/pexels_metadata/leaf_veins_macro.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 20 of leaf veins macro
#   Saved page 20 to /mnt/mls/data/pexels_metadata/leaf_veins_macro.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 21 of leaf veins macro
#   Saved page 21 to /mnt/mls/data/pexels_metadata/leaf_veins_macro.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 22 of leaf veins macro
#   Saved page 22 to /mnt/mls/data/pexels_metadata/leaf_veins_macro.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 23 of leaf veins macro
#   Saved page 23 to /mnt/mls/data/pexels_metadata/leaf_veins_macro.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 24 of leaf veins macro
#   Saved page 24 to /mnt/mls/data/pexels_metadata/leaf_veins_macro.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 25 of leaf veins macro
#   Saved page 25 to /mnt/mls/data/pexels_metadata/leaf_veins_macro.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 26 of leaf veins macro
#   Saved page 26 to /mnt/mls/data/pexels_metadata/leaf_veins_macro.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 27 of leaf veins macro
#   Saved page 27 to /mnt/mls/data/pexels_metadata/leaf_veins_macro.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 28 of leaf veins macro
#   Saved page 28 to /mnt/mls/data/pexels_metadata/leaf_veins_macro.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 29 of leaf veins macro
#   Saved page 29 to /mnt/mls/data/pexels_metadata/leaf_veins_macro.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 30 of leaf veins macro
#   Saved page 30 to /mnt/mls/data/pexels_metadata/leaf_veins_macro.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 31 of leaf veins macro
#   Saved page 31 to /mnt/mls/data/pexels_metadata/leaf_veins_macro.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 32 of leaf veins macro
#   Saved page 32 to /mnt/mls/data/pexels_metadata/leaf_veins_macro.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 33 of leaf veins macro
#   Saved page 33 to /mnt/mls/data/pexels_metadata/leaf_veins_macro.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 34 of leaf veins macro
#   Saved page 34 to /mnt/mls/data/pexels_metadata/leaf_veins_macro.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 35 of leaf veins macro
#   Saved page 35 to /mnt/mls/data/pexels_metadata/leaf_veins_macro.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 36 of leaf veins macro
#   Saved page 36 to /mnt/mls/data/pexels_metadata/leaf_veins_macro.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 37 of leaf veins macro
#   Saved page 37 to /mnt/mls/data/pexels_metadata/leaf_veins_macro.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 38 of leaf veins macro
#   Saved page 38 to /mnt/mls/data/pexels_metadata/leaf_veins_macro.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 39 of leaf veins macro
#   Saved page 39 to /mnt/mls/data/pexels_metadata/leaf_veins_macro.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 40 of leaf veins macro
#   Saved page 40 to /mnt/mls/data/pexels_metadata/leaf_veins_macro.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 41 of leaf veins macro
#   Saved page 41 to /mnt/mls/data/pexels_metadata/leaf_veins_macro.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 42 of leaf veins macro
#   Saved page 42 to /mnt/mls/data/pexels_metadata/leaf_veins_macro.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 43 of leaf veins macro
#   Saved page 43 to /mnt/mls/data/pexels_metadata/leaf_veins_macro.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 44 of leaf veins macro
#   Saved page 44 to /mnt/mls/data/pexels_metadata/leaf_veins_macro.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 45 of leaf veins macro
#   Saved page 45 to /mnt/mls/data/pexels_metadata/leaf_veins_macro.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 46 of leaf veins macro
#   Saved page 46 to /mnt/mls/data/pexels_metadata/leaf_veins_macro.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 47 of leaf veins macro
#   Saved page 47 to /mnt/mls/data/pexels_metadata/leaf_veins_macro.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 48 of leaf veins macro
#   Saved page 48 to /mnt/mls/data/pexels_metadata/leaf_veins_macro.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 49 of leaf veins macro
#   Saved page 49 to /mnt/mls/data/pexels_metadata/leaf_veins_macro.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 50 of leaf veins macro
#   Saved page 50 to /mnt/mls/data/pexels_metadata/leaf_veins_macro.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 51 of leaf veins macro
#   Saved page 51 to /mnt/mls/data/pexels_metadata/leaf_veins_macro.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 52 of leaf veins macro
#   Saved page 52 to /mnt/mls/data/pexels_metadata/leaf_veins_macro.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 53 of leaf veins macro
#   Saved page 53 to /mnt/mls/data/pexels_metadata/leaf_veins_macro.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 54 of leaf veins macro
#   Saved page 54 to /mnt/mls/data/pexels_metadata/leaf_veins_macro.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 55 of leaf veins macro
#   Saved page 55 to /mnt/mls/data/pexels_metadata/leaf_veins_macro.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 56 of leaf veins macro
#   Saved page 56 to /mnt/mls/data/pexels_metadata/leaf_veins_macro.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 57 of leaf veins macro
#   Saved page 57 to /mnt/mls/data/pexels_metadata/leaf_veins_macro.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 58 of leaf veins macro
#   Saved page 58 to /mnt/mls/data/pexels_metadata/leaf_veins_macro.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 59 of leaf veins macro
#   Saved page 59 to /mnt/mls/data/pexels_metadata/leaf_veins_macro.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 60 of leaf veins macro
#   Saved page 60 to /mnt/mls/data/pexels_metadata/leaf_veins_macro.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 61 of leaf veins macro
#   Saved page 61 to /mnt/mls/data/pexels_metadata/leaf_veins_macro.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 62 of leaf veins macro
#   Saved page 62 to /mnt/mls/data/pexels_metadata/leaf_veins_macro.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 63 of leaf veins macro
#   Saved page 63 to /mnt/mls/data/pexels_metadata/leaf_veins_macro.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 64 of leaf veins macro
#   Saved page 64 to /mnt/mls/data/pexels_metadata/leaf_veins_macro.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 65 of leaf veins macro
#   Saved page 65 to /mnt/mls/data/pexels_metadata/leaf_veins_macro.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 66 of leaf veins macro
#   Saved page 66 to /mnt/mls/data/pexels_metadata/leaf_veins_macro.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 67 of leaf veins macro
#   Saved page 67 to /mnt/mls/data/pexels_metadata/leaf_veins_macro.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 68 of leaf veins macro
#   Saved page 68 to /mnt/mls/data/pexels_metadata/leaf_veins_macro.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 69 of leaf veins macro
#   Saved page 69 to /mnt/mls/data/pexels_metadata/leaf_veins_macro.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 70 of leaf veins macro
#   Saved page 70 to /mnt/mls/data/pexels_metadata/leaf_veins_macro.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 71 of leaf veins macro
#   Saved page 71 to /mnt/mls/data/pexels_metadata/leaf_veins_macro.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 72 of leaf veins macro
#   Saved page 72 to /mnt/mls/data/pexels_metadata/leaf_veins_macro.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 73 of leaf veins macro
#   Saved page 73 to /mnt/mls/data/pexels_metadata/leaf_veins_macro.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 74 of leaf veins macro
#   Saved page 74 to /mnt/mls/data/pexels_metadata/leaf_veins_macro.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 75 of leaf veins macro
#   Saved page 75 to /mnt/mls/data/pexels_metadata/leaf_veins_macro.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 76 of leaf veins macro
#   Saved page 76 to /mnt/mls/data/pexels_metadata/leaf_veins_macro.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 77 of leaf veins macro
#   Saved page 77 to /mnt/mls/data/pexels_metadata/leaf_veins_macro.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 78 of leaf veins macro
#   Saved page 78 to /mnt/mls/data/pexels_metadata/leaf_veins_macro.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 79 of leaf veins macro
#   Saved page 79 to /mnt/mls/data/pexels_metadata/leaf_veins_macro.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 80 of leaf veins macro
#   Saved page 80 to /mnt/mls/data/pexels_metadata/leaf_veins_macro.parquet
# --- Finished 'leaf veins macro' with 80 pages ---
#
#
# --- Starting query: 'succulent cluster' ---
#
# https://api.pexels.com/v1/search
#   Fetched Page 1 of succulent cluster
#   Saved page 1 to /mnt/mls/data/pexels_metadata/succulent_cluster.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 2 of succulent cluster
#   Saved page 2 to /mnt/mls/data/pexels_metadata/succulent_cluster.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 3 of succulent cluster
#   Saved page 3 to /mnt/mls/data/pexels_metadata/succulent_cluster.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 4 of succulent cluster
#   Saved page 4 to /mnt/mls/data/pexels_metadata/succulent_cluster.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 5 of succulent cluster
#   Saved page 5 to /mnt/mls/data/pexels_metadata/succulent_cluster.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 6 of succulent cluster
#   Saved page 6 to /mnt/mls/data/pexels_metadata/succulent_cluster.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 7 of succulent cluster
#   Saved page 7 to /mnt/mls/data/pexels_metadata/succulent_cluster.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 8 of succulent cluster
#   Saved page 8 to /mnt/mls/data/pexels_metadata/succulent_cluster.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 9 of succulent cluster
#   Saved page 9 to /mnt/mls/data/pexels_metadata/succulent_cluster.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 10 of succulent cluster
#   Saved page 10 to /mnt/mls/data/pexels_metadata/succulent_cluster.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 11 of succulent cluster
#   Saved page 11 to /mnt/mls/data/pexels_metadata/succulent_cluster.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 12 of succulent cluster
#   Saved page 12 to /mnt/mls/data/pexels_metadata/succulent_cluster.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 13 of succulent cluster
#   Saved page 13 to /mnt/mls/data/pexels_metadata/succulent_cluster.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 14 of succulent cluster
#   Saved page 14 to /mnt/mls/data/pexels_metadata/succulent_cluster.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 15 of succulent cluster
#   Saved page 15 to /mnt/mls/data/pexels_metadata/succulent_cluster.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 16 of succulent cluster
#   Saved page 16 to /mnt/mls/data/pexels_metadata/succulent_cluster.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 17 of succulent cluster
#   Saved page 17 to /mnt/mls/data/pexels_metadata/succulent_cluster.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 18 of succulent cluster
#   Saved page 18 to /mnt/mls/data/pexels_metadata/succulent_cluster.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 19 of succulent cluster
#   Saved page 19 to /mnt/mls/data/pexels_metadata/succulent_cluster.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 20 of succulent cluster
#   Saved page 20 to /mnt/mls/data/pexels_metadata/succulent_cluster.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 21 of succulent cluster
#   Saved page 21 to /mnt/mls/data/pexels_metadata/succulent_cluster.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 22 of succulent cluster
#   Saved page 22 to /mnt/mls/data/pexels_metadata/succulent_cluster.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 23 of succulent cluster
#   Saved page 23 to /mnt/mls/data/pexels_metadata/succulent_cluster.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 24 of succulent cluster
#   Saved page 24 to /mnt/mls/data/pexels_metadata/succulent_cluster.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 25 of succulent cluster
#   Saved page 25 to /mnt/mls/data/pexels_metadata/succulent_cluster.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 26 of succulent cluster
#   Saved page 26 to /mnt/mls/data/pexels_metadata/succulent_cluster.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 27 of succulent cluster
#   Saved page 27 to /mnt/mls/data/pexels_metadata/succulent_cluster.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 28 of succulent cluster
#   Saved page 28 to /mnt/mls/data/pexels_metadata/succulent_cluster.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 29 of succulent cluster
#   Saved page 29 to /mnt/mls/data/pexels_metadata/succulent_cluster.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 30 of succulent cluster
#   Saved page 30 to /mnt/mls/data/pexels_metadata/succulent_cluster.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 31 of succulent cluster
#   Saved page 31 to /mnt/mls/data/pexels_metadata/succulent_cluster.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 32 of succulent cluster
#   Saved page 32 to /mnt/mls/data/pexels_metadata/succulent_cluster.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 33 of succulent cluster
#   Saved page 33 to /mnt/mls/data/pexels_metadata/succulent_cluster.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 34 of succulent cluster
#   Saved page 34 to /mnt/mls/data/pexels_metadata/succulent_cluster.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 35 of succulent cluster
#   Saved page 35 to /mnt/mls/data/pexels_metadata/succulent_cluster.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 36 of succulent cluster
#   Saved page 36 to /mnt/mls/data/pexels_metadata/succulent_cluster.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 37 of succulent cluster
#   Saved page 37 to /mnt/mls/data/pexels_metadata/succulent_cluster.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 38 of succulent cluster
#   Saved page 38 to /mnt/mls/data/pexels_metadata/succulent_cluster.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 39 of succulent cluster
#   Saved page 39 to /mnt/mls/data/pexels_metadata/succulent_cluster.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 40 of succulent cluster
#   Saved page 40 to /mnt/mls/data/pexels_metadata/succulent_cluster.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 41 of succulent cluster
#   Saved page 41 to /mnt/mls/data/pexels_metadata/succulent_cluster.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 42 of succulent cluster
#   Saved page 42 to /mnt/mls/data/pexels_metadata/succulent_cluster.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 43 of succulent cluster
#   Saved page 43 to /mnt/mls/data/pexels_metadata/succulent_cluster.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 44 of succulent cluster
#   Saved page 44 to /mnt/mls/data/pexels_metadata/succulent_cluster.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 45 of succulent cluster
#   Saved page 45 to /mnt/mls/data/pexels_metadata/succulent_cluster.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 46 of succulent cluster
#   Saved page 46 to /mnt/mls/data/pexels_metadata/succulent_cluster.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 47 of succulent cluster
#   Saved page 47 to /mnt/mls/data/pexels_metadata/succulent_cluster.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 48 of succulent cluster
#   Saved page 48 to /mnt/mls/data/pexels_metadata/succulent_cluster.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 49 of succulent cluster
#   Saved page 49 to /mnt/mls/data/pexels_metadata/succulent_cluster.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 50 of succulent cluster
#   Saved page 50 to /mnt/mls/data/pexels_metadata/succulent_cluster.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 51 of succulent cluster
#   Saved page 51 to /mnt/mls/data/pexels_metadata/succulent_cluster.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 52 of succulent cluster
#   Saved page 52 to /mnt/mls/data/pexels_metadata/succulent_cluster.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 53 of succulent cluster
#   Saved page 53 to /mnt/mls/data/pexels_metadata/succulent_cluster.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 54 of succulent cluster
#   Saved page 54 to /mnt/mls/data/pexels_metadata/succulent_cluster.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 55 of succulent cluster
#   Saved page 55 to /mnt/mls/data/pexels_metadata/succulent_cluster.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 56 of succulent cluster
#   Saved page 56 to /mnt/mls/data/pexels_metadata/succulent_cluster.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 57 of succulent cluster
#   Saved page 57 to /mnt/mls/data/pexels_metadata/succulent_cluster.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 58 of succulent cluster
#   Saved page 58 to /mnt/mls/data/pexels_metadata/succulent_cluster.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 59 of succulent cluster
#   Saved page 59 to /mnt/mls/data/pexels_metadata/succulent_cluster.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 60 of succulent cluster
#   Saved page 60 to /mnt/mls/data/pexels_metadata/succulent_cluster.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 61 of succulent cluster
#   Saved page 61 to /mnt/mls/data/pexels_metadata/succulent_cluster.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 62 of succulent cluster
#   Saved page 62 to /mnt/mls/data/pexels_metadata/succulent_cluster.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 63 of succulent cluster
#   Saved page 63 to /mnt/mls/data/pexels_metadata/succulent_cluster.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 64 of succulent cluster
#   Saved page 64 to /mnt/mls/data/pexels_metadata/succulent_cluster.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 65 of succulent cluster
#   Saved page 65 to /mnt/mls/data/pexels_metadata/succulent_cluster.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 66 of succulent cluster
#   Saved page 66 to /mnt/mls/data/pexels_metadata/succulent_cluster.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 67 of succulent cluster
#   Saved page 67 to /mnt/mls/data/pexels_metadata/succulent_cluster.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 68 of succulent cluster
#   Saved page 68 to /mnt/mls/data/pexels_metadata/succulent_cluster.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 69 of succulent cluster
#   Saved page 69 to /mnt/mls/data/pexels_metadata/succulent_cluster.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 70 of succulent cluster
#   Saved page 70 to /mnt/mls/data/pexels_metadata/succulent_cluster.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 71 of succulent cluster
#   Saved page 71 to /mnt/mls/data/pexels_metadata/succulent_cluster.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 72 of succulent cluster
#   Saved page 72 to /mnt/mls/data/pexels_metadata/succulent_cluster.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 73 of succulent cluster
#   Saved page 73 to /mnt/mls/data/pexels_metadata/succulent_cluster.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 74 of succulent cluster
#   Saved page 74 to /mnt/mls/data/pexels_metadata/succulent_cluster.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 75 of succulent cluster
#   Saved page 75 to /mnt/mls/data/pexels_metadata/succulent_cluster.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 76 of succulent cluster
#   Saved page 76 to /mnt/mls/data/pexels_metadata/succulent_cluster.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 77 of succulent cluster
#   Saved page 77 to /mnt/mls/data/pexels_metadata/succulent_cluster.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 78 of succulent cluster
#   Saved page 78 to /mnt/mls/data/pexels_metadata/succulent_cluster.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 79 of succulent cluster
#   Saved page 79 to /mnt/mls/data/pexels_metadata/succulent_cluster.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 80 of succulent cluster
#   Saved page 80 to /mnt/mls/data/pexels_metadata/succulent_cluster.parquet
# --- Finished 'succulent cluster' with 80 pages ---
#
#
# --- Starting query: 'tropical foliage pattern' ---
#
# https://api.pexels.com/v1/search
#   Fetched Page 1 of tropical foliage pattern
#   Saved page 1 to /mnt/mls/data/pexels_metadata/tropical_foliage_pattern.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 2 of tropical foliage pattern
#   Saved page 2 to /mnt/mls/data/pexels_metadata/tropical_foliage_pattern.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 3 of tropical foliage pattern
#   Saved page 3 to /mnt/mls/data/pexels_metadata/tropical_foliage_pattern.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 4 of tropical foliage pattern
#   Saved page 4 to /mnt/mls/data/pexels_metadata/tropical_foliage_pattern.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 5 of tropical foliage pattern
#   Saved page 5 to /mnt/mls/data/pexels_metadata/tropical_foliage_pattern.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 6 of tropical foliage pattern
#   Saved page 6 to /mnt/mls/data/pexels_metadata/tropical_foliage_pattern.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 7 of tropical foliage pattern
#   Saved page 7 to /mnt/mls/data/pexels_metadata/tropical_foliage_pattern.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 8 of tropical foliage pattern
#   Saved page 8 to /mnt/mls/data/pexels_metadata/tropical_foliage_pattern.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 9 of tropical foliage pattern
#   Saved page 9 to /mnt/mls/data/pexels_metadata/tropical_foliage_pattern.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 10 of tropical foliage pattern
#   Saved page 10 to /mnt/mls/data/pexels_metadata/tropical_foliage_pattern.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 11 of tropical foliage pattern
#   Saved page 11 to /mnt/mls/data/pexels_metadata/tropical_foliage_pattern.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 12 of tropical foliage pattern
#   Saved page 12 to /mnt/mls/data/pexels_metadata/tropical_foliage_pattern.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 13 of tropical foliage pattern
#   Saved page 13 to /mnt/mls/data/pexels_metadata/tropical_foliage_pattern.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 14 of tropical foliage pattern
#   Saved page 14 to /mnt/mls/data/pexels_metadata/tropical_foliage_pattern.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 15 of tropical foliage pattern
#   Saved page 15 to /mnt/mls/data/pexels_metadata/tropical_foliage_pattern.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 16 of tropical foliage pattern
#   Saved page 16 to /mnt/mls/data/pexels_metadata/tropical_foliage_pattern.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 17 of tropical foliage pattern
#   Saved page 17 to /mnt/mls/data/pexels_metadata/tropical_foliage_pattern.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 18 of tropical foliage pattern
#   Saved page 18 to /mnt/mls/data/pexels_metadata/tropical_foliage_pattern.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 19 of tropical foliage pattern
#   Saved page 19 to /mnt/mls/data/pexels_metadata/tropical_foliage_pattern.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 20 of tropical foliage pattern
#   Saved page 20 to /mnt/mls/data/pexels_metadata/tropical_foliage_pattern.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 21 of tropical foliage pattern
#   Saved page 21 to /mnt/mls/data/pexels_metadata/tropical_foliage_pattern.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 22 of tropical foliage pattern
#   Saved page 22 to /mnt/mls/data/pexels_metadata/tropical_foliage_pattern.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 23 of tropical foliage pattern
#   Saved page 23 to /mnt/mls/data/pexels_metadata/tropical_foliage_pattern.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 24 of tropical foliage pattern
#   Saved page 24 to /mnt/mls/data/pexels_metadata/tropical_foliage_pattern.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 25 of tropical foliage pattern
#   Saved page 25 to /mnt/mls/data/pexels_metadata/tropical_foliage_pattern.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 26 of tropical foliage pattern
#   Saved page 26 to /mnt/mls/data/pexels_metadata/tropical_foliage_pattern.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 27 of tropical foliage pattern
#   Saved page 27 to /mnt/mls/data/pexels_metadata/tropical_foliage_pattern.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 28 of tropical foliage pattern
#   Saved page 28 to /mnt/mls/data/pexels_metadata/tropical_foliage_pattern.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 29 of tropical foliage pattern
#   Saved page 29 to /mnt/mls/data/pexels_metadata/tropical_foliage_pattern.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 30 of tropical foliage pattern
#   Saved page 30 to /mnt/mls/data/pexels_metadata/tropical_foliage_pattern.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 31 of tropical foliage pattern
#   Saved page 31 to /mnt/mls/data/pexels_metadata/tropical_foliage_pattern.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 32 of tropical foliage pattern
#   Saved page 32 to /mnt/mls/data/pexels_metadata/tropical_foliage_pattern.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 33 of tropical foliage pattern
#   Saved page 33 to /mnt/mls/data/pexels_metadata/tropical_foliage_pattern.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 34 of tropical foliage pattern
#   Saved page 34 to /mnt/mls/data/pexels_metadata/tropical_foliage_pattern.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 35 of tropical foliage pattern
#   Saved page 35 to /mnt/mls/data/pexels_metadata/tropical_foliage_pattern.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 36 of tropical foliage pattern
#   Saved page 36 to /mnt/mls/data/pexels_metadata/tropical_foliage_pattern.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 37 of tropical foliage pattern
#   Saved page 37 to /mnt/mls/data/pexels_metadata/tropical_foliage_pattern.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 38 of tropical foliage pattern
#   Saved page 38 to /mnt/mls/data/pexels_metadata/tropical_foliage_pattern.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 39 of tropical foliage pattern
#   Saved page 39 to /mnt/mls/data/pexels_metadata/tropical_foliage_pattern.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 40 of tropical foliage pattern
#   Saved page 40 to /mnt/mls/data/pexels_metadata/tropical_foliage_pattern.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 41 of tropical foliage pattern
#   Saved page 41 to /mnt/mls/data/pexels_metadata/tropical_foliage_pattern.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 42 of tropical foliage pattern
#   Saved page 42 to /mnt/mls/data/pexels_metadata/tropical_foliage_pattern.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 43 of tropical foliage pattern
#   Saved page 43 to /mnt/mls/data/pexels_metadata/tropical_foliage_pattern.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 44 of tropical foliage pattern
#   Saved page 44 to /mnt/mls/data/pexels_metadata/tropical_foliage_pattern.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 45 of tropical foliage pattern
#   Saved page 45 to /mnt/mls/data/pexels_metadata/tropical_foliage_pattern.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 46 of tropical foliage pattern
#   Saved page 46 to /mnt/mls/data/pexels_metadata/tropical_foliage_pattern.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 47 of tropical foliage pattern
#   Saved page 47 to /mnt/mls/data/pexels_metadata/tropical_foliage_pattern.parquet
# https://api.pexels.com/v1/search
#   Fetched Page 48 of tropical foliage pattern
#   Saved page 48 to /mnt/mls/data/pexels_metadata/tropical_foliage_pattern.parquet
# https://api.pexels.com/v1/search
#   [ERROR] Failed on page 49 of 'tropical foliage pattern': 'page'
# --- Finished 'tropical foliage pattern' with 49 pages ---
#
#
# --- Starting query: 'jungle canopy plant' ---
#
# https://api.pexels.com/v1/search
#   [ERROR] Failed on page 1 of 'jungle canopy plant': 'page'
# --- Finished 'jungle canopy plant' with 1 pages ---
#
#
# --- Starting query: 'young sprout macro' ---
#
# https://api.pexels.com/v1/search
#   [ERROR] Failed on page 1 of 'young sprout macro': 'page'
# --- Finished 'young sprout macro' with 1 pages ---

# %%
parquet_dir = Path("/mnt/mls/data/pexels_metadata")
parquet_files = list(parquet_dir.glob("*.parquet"))

df_master = pd.concat([pd.read_parquet(f) for f in parquet_files], ignore_index=True)
print(f"Total combined records: {len(df_master)}")
# Out:
# Total combined records: 16799

# %%
df_master['original'] = df_master['src'].apply(lambda x: x['original'])

# %%
bad_phrases = set()

# === 1. Indoor Decor & Furniture Phrases ===
bad_phrases.update({
    "light bulb",
    "coffee table",
    "wall art",
    "interior design",
    "dining room",
    "living room",
    "bedroom",
    "home office",
    "window sill", "bathroom counter",
    "sofa chair",
    "table lamp",
    "picture frame",
    "picture wall",
    "flat lay"
})

# === 2. Garden, Patio, & Staging Items ===
bad_phrases.update({
    "potted plant",
    "hanging basket",
    "urban garden",
    "flower vase",
    "fruit basket",
    "wooden deck",
    "picnic table",
    "lawn ornament",
    "garden gnome"
})

# === 3. Miscellaneous Environmental Distractions ===
bad_phrases.update({
    "city park",
    "smart phone",
    "art installation",
    "power plant",
    "test tube",
    "tree bark"
})

# %%
bad_lemmas = set()

# === 1. People, Body Parts, Relationships, Gender ===
bad_lemmas.update({
    "man", "woman", "male", "female", "person", "client",
    "employee", "group", "volunteer", "gardener", "students",
    "child", "kid",
    "girl", "boy", "son", "daughter", "mom", "dad", "mother", "father",
    "bride", "groom", "couple", "romance", "intimate",
    "hand", "foot", "leg", "arm", "chest", "head", "eye", "nose", "ear", "mouth", "face",
    "young", "old", "pose", "photographer", "hombre", "nutritionist", "florist", "arrange",
    "businessman", "businesswoman"
})

# === 2. Animals & Insects ===
bad_lemmas.update({
    "cat", "dog", "butterfly", "bee", "caterpillar", "squirrel", "bird",
    "perch", "spider", "web", "insect", "fly", "furry", "snail", "slug",
    "honeybee", "beetle", "tick", "frog", "lynx", "chameleon", "bumblebee",
    "hummingbird", "hovers", "ladybug", "moth", "peacock", "snake", "cobra", "python"
                                                                             "playful", "obedient"
})

# === 3. Furniture, Decor, Indoor Items ===
bad_lemmas.update({
    "table", "bed", "couch", "chair", "pillow", "blanket", "mirror", "curtain", "carpet",
    "rug", "lamp", "ceiling", "floor", "tile", "window", "shelf", "frame", "decor",
    "design", "wall", "painting", "print", "art", "style", "bottle", "vase", "fashion",
    "portrait", "studio", "bedding", "journal", "library", "bookshelves", "card", "lipstick",
    "blazer", "supplements", "interior", "stock", "photo", "free", "sunglasses", "drink",
    "flatlay", "paper", "fabric", "candle", "arrangement", "pitcher", "potted", "bible",
    "hanging", "hang", "reading", "nook", "bouquet", "cabinet", "drawer"
})

# === 4. Office, Tech, Work Items ===
bad_lemmas.update({
    "book", "notebook", "pen", "pencil", "laptop", "smartphone", "keyboard",
    "computer", "desk", "office", "setup", "device", "tablet", "work", "room", "scissors",
    "business", "magazine", "finance", "money", "bill", "dollar", "teamwork", "team",
    "suit", "sneakers", "shoes", "network", "cable",
    "nutritious", "pants", "dress", "wireless", "headphone", "jacket"
})

# === 5. Containers, Kitchen, and Medical Props ===
bad_lemmas.update({
    "basket", "bucket", "pot", "planter", "terrarium", "mug", "crate", "box",
    "cup", "spoon", "fork", "plate", "dropper", "vial", "tool", "mortar", "medicine",
    "bowl", "board", "document", "sink", "can", "tube", "cocktail", "refresh",
    "jar", "slice", "teapot", "herb", "cell", "platter", "pan",
    "remedies", "ingredient"
})

# === 6. Abstract, Model, or Visual Noise ===
bad_lemmas.update({
    "closeup", "shadow", "reflection", "model", "figure", "stylish",
    "sculpture", "statue", "diversity", "mockup", "artistic", "composition", "word", "letter", "aerial",
    "silhouette", "microscopic",
})

# === 7. Food, Fruit, Culinary ===
bad_lemmas.update({
    "fruit", "produce", "food", "kitchen", "grape", "cherry", "cherries",
    "tomato", "nut", "root", "culinary", "wine", "strawberry", "ripe", "harvest", "mushroom", "fungus", "fungi", "hop",
    "pineapple", "berry", "pumpkin", "coconut", "hazelnut", "walnut", "penut", "artichoke", "juice", "juicy", "fresh",
    "sliced", "meat", "skewered", "grill", "egg", "bacon", "pasta"
})

# === 8. Landscape, Outdoors, Urban ===
bad_lemmas.update({
    "farm", "pasture", "agriculture", "farming", "tractor", "trailer",
    "combine", "barn", "gravel", "path", "bench", "fence", "porch",
    "balcony", "building", "road", "driveway", "street", "bridge", "valley",
    "skyline", "resort", "pool", "travel", "leisure", "walkway", "roof", "environment",
    "countryside", "country", "urban", "exterior", "home",
    "house", "scene", "pathway", "wooden", "wood", "sign", "footpath", "forest", "ocean", "mountains", "desert",
    "rustic", "river", "lake", "waterfall", "fountain", "pond", "logs", "firewood", "sea"
})

# === 9. Religious, Monumental, Public Architecture ===
bad_lemmas.update({
    "temple", "church", "mosque", "graveyard", "tombstone", "skeleton", "store", "storefront"
})

# === 10. Vehicles, Transportation, Infrastructure ===
bad_lemmas.update({
    "vehicle", "truck", "bus", "bicycle", "bike", "pipe", "plumbing", "car", "speedometer"
})

# === 11. Industrial & Work-Related ===
bad_lemmas.update({
    "industrial", "steel", "structure", "laboratory", "tin", "copper", "column",
    "concrete", "wire", "barbed", "rust", "disc", "rock", "chunk", "illuminate",
    "LED", "light", "museum", "architecture", "production", "product", "stone", "garage", "door", "cottage", "college",
    "campus", "townhouse", "homeopathy"
})

# === 12. Miscellaneous Tools & Actions ===
bad_lemmas.update({
    "shovel", "hold", "dna", "helix"
})

# %%
from collections import Counter
import spacy

nlp = spacy.load("en_core_web_sm")
word_counts = Counter()


def is_keep(token):
    return token.is_alpha and not token.is_stop and not token.is_punct


for alt in df_master['alt']:
    doc = nlp(alt)
    for token in doc:
        if is_keep(token):
            word_counts[token.lemma_.lower()] += 1
# Out:
# /mnt/mls/venv/lib/python3.12/site-packages/torch/cuda/__init__.py:734: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")

# %%
def should_reject(text: str, bad_lemmas: set, bad_phrases: set) -> dict:
    """
    Evaluates whether a given alt-text string should be rejected based on exclusion rules.

    The function checks for:
    - Non-ASCII characters
    - Empty or whitespace-only text
    - Presence of undesirable phrases (substring match)
    - Presence of undesirable lemmas or tokens (via spaCy NLP)

    Args:
        text (str): The alt-text string to evaluate.
        bad_lemmas (set): A set of lowercased lemmatized words to reject.
        bad_phrases (set): A set of exact phrases that trigger rejection.

    Returns:
        dict: A dictionary with:
            - "valid" (bool): True if the text passes all checks.
            - "reasons" (list | None): A list of reasons for rejection, or None if valid.
    """

    reasons = []

    if not all(ord(c) < 128 for c in text):
        reasons.append("non-ascii characters")

    if not text or text.strip() == "":
        reasons.append("blank text")

    text_lower = text.lower()
    for phrase in bad_phrases:
        if phrase in text_lower:
            reasons.append(f"bad phrase: '{phrase}'")

    doc = nlp(text)
    for token in doc:
        lemma = token.lemma_.lower()
        raw = token.text.lower().replace("-", "")
        if lemma in bad_lemmas:
            reasons.append(f"bad lemma: '{lemma}'")
        if raw in bad_lemmas:
            reasons.append(f"bad token: '{raw}'")

    return {"valid": len(reasons) == 0, "reasons": reasons if reasons else None}

# %%
def save_image_by_size(
        url: str,
        base_dir: str | None = None,
        label: str | None = None,
        alt_text: str = '',
        reasons=None
) -> None:

    """
    Downloads an image from a URL, saves it in a structured directory based on resolution,
    and writes associated metadata to a JSON file.

    Folder structure:
        [base_dir]/clean/[label]/[width]/[height]/[filename]

    Args:
        url (str): The URL of the image to download.
        base_dir (str | None): Base directory where images and metadata will be stored.
        label (str | None): Optional category or query label for organizing images.
        alt_text (str): Alt-text or caption associated with the image.
        reasons (list | None): Optional reasons for acceptance or context metadata.
                               If None, the image is considered "valid".

    Returns:
        None
    """

    filename = urlparse(url).path.split("/")[-1]
    response = requests.get(url, verify=certifi.where())
    image = Image.open(BytesIO(response.content)).convert("RGB")
    width, height = image.size

    folder_path = f'{base_dir}/clean/{label}/{width}/{height}'
    os.makedirs(folder_path, exist_ok=True)
    image.save(f'{folder_path}/{filename}')

    metadata = {
        "label": label,
        "alt_text": alt_text,
        "reasons": reasons if reasons else "valid",
        "url": url,
        "dimensions": {"width": width, "height": height},
        "filename": filename
    }

    filename_root = filename.split('.')[0]
    with open(f'{folder_path}/{filename_root}.json', 'w') as f:
        json.dump(metadata, f, indent=2)

    print(f"Saved to: {folder_path}/{filename}")

# %%
def save_image_to_rejects(url: str, base_dir: str | None = None, label: str | None = None,
                          alt_text: str = '', reasons: list | None = None) -> None:
    """
    Downloads an image from a URL and saves it to a 'rejected' folder with accompanying metadata.

    Folder structure:
        [base_dir]/rejected/[label]/[filename]

    Args:
        url (str): The URL of the image to download.
        base_dir (str | None): Base directory where rejected images and metadata will be stored.
        label (str | None): Optional label or query term used to organize rejected images.
        alt_text (str): Alt-text or caption associated with the image.
        reasons (list | None): List of rejection reasons. If None, defaults to ["unspecified"].

    Returns:
        None
    """

    filename = urlparse(url).path.split("/")[-1]
    response = requests.get(url, verify=certifi.where())
    image = Image.open(BytesIO(response.content)).convert("RGB")

    folder_path = f'{base_dir}/rejected/{label}'
    os.makedirs(folder_path, exist_ok=True)
    image.save(f'{folder_path}/{filename}')

    filename_root = filename.split('.')[0]
    metadata = {
        "label": label,
        "alt_text": alt_text,
        "reasons": reasons if reasons else ["unspecified"],
        "url": url,
    }

    with open(f'{folder_path}/{filename_root}.json', 'w') as f:
        json.dump(metadata, f, indent=2)

    print(f"[REJECTED] Saved to: {folder_path}/{filename}")

# %%
clean_count = 0
rejected_count = 0

for index, row in df_master.iterrows():
    result = should_reject(text=row['alt'], bad_lemmas=bad_lemmas, bad_phrases=bad_phrases)

    print(result)

    if not result['valid']:
        rejected_count += 1
        save_image_to_rejects(
            url=row['original'],
            base_dir=images_dir,
            label=query_label,
            alt_text=row['alt'],
            reasons=result['reasons']
        )

    else:
        clean_count += 1
        save_image_by_size(
            url=row['original'],
            base_dir=images_dir,
            label=query_label,
            alt_text=row['alt'],
        )

print(Fore.GREEN + f"\nClean images: {clean_count}")
print(Fore.RED + f"Rejected images: {rejected_count}")
print(Fore.YELLOW + f"Acceptance rate: {clean_count / (clean_count + rejected_count):.2%}\n" + Style.RESET_ALL)
# Out:
# {'valid': False, 'reasons': ["bad lemma: 'berry'", "bad token: 'berry'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/pexels-photo-31979873.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/3456/5184/pexels-photo-31964236.jpeg
# {'valid': False, 'reasons': ['blank text']}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/pexels-photo-31968576.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/3120/4160/pexels-photo-1226302.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/4019/6029/pexels-photo-4594030.jpeg
# {'valid': False, 'reasons': ["bad lemma: 'artistic'", "bad token: 'artistic'", "bad lemma: 'shadow'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/pexels-photo-1204941.jpeg
# {'valid': False, 'reasons': ["bad lemma: 'coconut'", "bad token: 'coconut'", "bad lemma: 'shadow'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/meadow-grass-palm-tree-forest-plenty-of-natural-light-47334.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/4480/6720/pexels-photo-4593876.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/3456/5184/pexels-photo-2409038.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/2000/3000/pexels-photo-1524235.jpeg
# {'valid': False, 'reasons': ["bad lemma: 'light'", "bad token: 'light'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/pexels-photo-1172675.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/4480/6720/pexels-photo-4622253.jpeg
# {'valid': False, 'reasons': ["bad lemma: 'shadow'", "bad lemma: 'wall'", "bad token: 'wall'", "bad lemma: 'scene'", "bad token: 'scene'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/pexels-photo-30123038.jpeg
# {'valid': False, 'reasons': ["bad lemma: 'design'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/pexels-photo-2609107.jpeg
# {'valid': False, 'reasons': ["bad lemma: 'fresh'", "bad token: 'fresh'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/pexels-photo-1592119.jpeg
# {'valid': False, 'reasons': ["bad lemma: 'artistic'", "bad token: 'artistic'", "bad lemma: 'photo'", "bad token: 'photo'", "bad lemma: 'light'", "bad token: 'light'", "bad lemma: 'shadow'", "bad token: 'shadow'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/pexels-photo-3721044.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/2848/4272/pexels-photo-3571551.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/3840/5760/pexels-photo-2563742.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/1920/1080/green-leaf-natural-wallpaper-royalty-free-66869.jpeg
# {'valid': False, 'reasons': ["bad lemma: 'fresh'", "bad token: 'fresh'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/pexels-photo-2215534.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/6000/4000/pexels-photo-1276518.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/3264/2448/pexels-photo-2318554.jpeg
# {'valid': False, 'reasons': ["bad lemma: 'artistic'", "bad token: 'artistic'", "bad lemma: 'shadow'", "bad token: 'shadow'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/pexels-photo-10683150.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/2155/2693/pexels-photo-136740.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/5280/3520/pexels-photo-1420019.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/2656/3984/pexels-photo-1216345.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/4480/6720/pexels-photo-4599918.jpeg
# {'valid': False, 'reasons': ["bad lemma: 'wall'", "bad token: 'wall'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/pexels-photo-11741414.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/2570/3427/pexels-photo-8058644.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/2656/3984/pexels-photo-1054018.jpeg
# {'valid': False, 'reasons': ["bad lemma: 'artistic'", "bad token: 'artistic'", "bad lemma: 'design'", "bad token: 'design'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/pexels-photo-68556.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/4363/6544/pexels-photo-4599906.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/2048/1365/pexels-photo-673535.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/7282/4857/pexels-photo-1190906.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/3024/4032/pexels-photo-3293037.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/4928/3264/leaf-leaves-colorful-green-57436.jpeg
# {'valid': False, 'reasons': ["bad lemma: 'fresh'", "bad token: 'fresh'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/pexels-photo-2473990.jpeg
# {'valid': False, 'reasons': ["bad lemma: 'illuminate'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/pexels-photo-15676266.jpeg
# {'valid': False, 'reasons': ["bad lemma: 'hand'", "bad token: 'hand'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/pexels-photo-1492364.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/4480/6720/pexels-photo-4594033.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/5760/3840/pexels-photo-3789449.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/3000/4000/pexels-photo-10788135.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/4480/6720/pexels-photo-5942508.jpeg
# {'valid': False, 'reasons': ["bad lemma: 'concrete'", "bad token: 'concrete'", "bad lemma: 'wall'", "bad token: 'wall'", "bad lemma: 'design'", "bad token: 'design'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/pexels-photo-212944.jpeg
# {'valid': False, 'reasons': ["bad lemma: 'wall'", "bad token: 'wall'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/pexels-photo-1520620.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/4000/6000/pexels-photo-28084134.jpeg
# {'valid': False, 'reasons': ["bad lemma: 'shadow'", "bad lemma: 'wall'", "bad token: 'wall'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/pexels-photo-6486618.jpeg
# {'valid': False, 'reasons': ["bad lemma: 'design'", "bad token: 'design'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/pexels-photo-6707626.jpeg
# {'valid': False, 'reasons': ["bad lemma: 'design'", "bad lemma: 'shadow'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/leaves-green-shadow-play-royalty-free-70346.jpeg
# {'valid': False, 'reasons': ["bad lemma: 'shadow'", "bad token: 'shadow'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/pexels-photo-8793991.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/3024/4032/pexels-photo-20529737.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/5000/4000/pexels-photo-4058958.jpeg
# {'valid': False, 'reasons': ["bad lemma: 'light'", "bad token: 'light'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/pexels-photo-1702495.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/3024/4032/pexels-photo-4636786.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/3984/2656/pexels-photo-1403400.jpeg
# {'valid': False, 'reasons': ["bad lemma: 'stylish'", "bad token: 'stylish'", "bad lemma: 'wooden'", "bad token: 'wooden'", "bad lemma: 'frame'", "bad lemma: 'rustic'", "bad token: 'rustic'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/pexels-photo-1875388.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/6000/4000/pexels-photo-3306986.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/6000/4000/pexels-photo-943899.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/4000/5000/pexels-photo-20261506.jpeg
# {'valid': False, 'reasons': ["bad lemma: 'shadow'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/pexels-photo-3821378.jpeg
# {'valid': False, 'reasons': ["bad lemma: 'decor'", "bad token: 'decor'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/pexels-photo-13276952.jpeg
# {'valid': False, 'reasons': ["bad lemma: 'shadow'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/pexels-photo-6793888.jpeg
# {'valid': False, 'reasons': ["bad lemma: 'light'", "bad token: 'light'", "bad lemma: 'window'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/pexels-photo-6496129.jpeg
# {'valid': False, 'reasons': ["bad lemma: 'structure'", "bad token: 'structure'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/pexels-photo-13217566.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/2606/3648/pexels-photo-2178028.jpeg
# {'valid': False, 'reasons': ["bad lemma: 'fresh'", "bad token: 'fresh'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/pexels-photo-7013612.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/2595/3456/pexels-photo-2004324.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/4000/6000/pexels-photo-2873478.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/3717/5575/pexels-photo-4870614.jpeg
# {'valid': False, 'reasons': ["bad lemma: 'tile'", "bad lemma: 'wall'", "bad token: 'wall'", "bad lemma: 'light'", "bad token: 'light'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/pexels-photo-16753490.jpeg
# {'valid': False, 'reasons': ["bad lemma: 'shadow'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/pexels-photo-14365803.jpeg
# {'valid': False, 'reasons': ["bad lemma: 'artistic'", "bad token: 'artistic'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/pexels-photo-15838443.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/2394/3591/pexels-photo-1813508.jpeg
# {'valid': False, 'reasons': ["bad lemma: 'forest'", "bad token: 'forest'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/pexels-photo-6039237.jpeg
# {'valid': False, 'reasons': ["bad lemma: 'composition'", "bad token: 'composition'", "bad lemma: 'shadow'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/pexels-photo-7110339.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/2752/3440/pexels-photo-7354790.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/6000/4000/pexels-photo-7245607.jpeg
# {'valid': False, 'reasons': ["bad lemma: 'fresh'", "bad token: 'fresh'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/pexels-photo-7013611.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/4000/3000/pexels-photo-926641.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/4288/2848/plant-leaf-macro-palm-39569.jpeg
# {'valid': False, 'reasons': ["bad lemma: 'structure'", "bad token: 'structure'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/pexels-photo-4119179.jpeg
# {'valid': False, 'reasons': ["bad lemma: 'forest'", "bad token: 'forest'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/pexels-photo-6039237.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/3000/4000/pexels-photo-2000595.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/4288/2848/plant-leaf-macro-palm-39569.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/4000/3000/pexels-photo-926641.jpeg
# {'valid': False, 'reasons': ["bad lemma: 'studio'", "bad token: 'studio'", "bad lemma: 'ripe'", "bad token: 'ripe'", "bad lemma: 'pineapple'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/pexels-photo-7194795.jpeg
# {'valid': False, 'reasons': ["bad lemma: 'butterfly'", "bad token: 'butterfly'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/pexels-photo-1242454.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/3984/2656/pexels-photo-1403404.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/5760/3840/pexels-photo-2155502.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/1778/2822/pexels-photo-3117175.jpeg
# {'valid': False, 'reasons': ["bad lemma: 'fresh'", "bad token: 'fresh'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/pexels-photo-2563854.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/3456/4314/pexels-photo-3708554.jpeg
# {'valid': False, 'reasons': ["bad lemma: 'photo'", "bad token: 'photo'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/pexels-photo-2918592.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/6000/4000/pexels-photo-2873476.jpeg
# {'valid': False, 'reasons': ["bad lemma: 'forest'", "bad token: 'forest'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/pexels-photo-2510600.jpeg
# {'valid': False, 'reasons': ["bad lemma: 'rustic'", "bad token: 'rustic'", "bad lemma: 'wooden'", "bad token: 'wooden'", "bad lemma: 'wall'", "bad token: 'wall'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/pexels-photo-1931142.jpeg
# {'valid': False, 'reasons': ["bad lemma: 'ocean'", "bad token: 'ocean'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/beach-leaf-green-nature-39573.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/6283/4189/pexels-photo-4596792.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/5109/3406/pexels-photo-6455059.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/4000/6000/pexels-photo-6437700.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/2848/4272/pexels-photo-9929233.jpeg
# {'valid': False, 'reasons': ["bad lemma: 'shadow'", "bad token: 'shadow'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/pexels-photo-16326512.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/3956/5935/pexels-photo-15056010.jpeg
# {'valid': False, 'reasons': ["bad lemma: 'forest'", "bad token: 'forest'", "bad lemma: 'environment'", "bad token: 'environment'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/pexels-photo-18517349.jpeg
# {'valid': False, 'reasons': ["bad lemma: 'fresh'", "bad token: 'fresh'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/pexels-photo-1883932.jpeg
# {'valid': False, 'reasons': ["bad lemma: 'illuminate'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/pexels-photo-6437704.jpeg
# {'valid': False, 'reasons': ["bad lemma: 'design'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/pexels-photo-5418830.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/2333/3500/pexels-photo-5528802.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/3588/5382/pexels-photo-4590417.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/6720/4480/pexels-photo-4593982.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/4480/6720/pexels-photo-4593900.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/4000/6000/pexels-photo-2677343.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/4480/6720/pexels-photo-5978509.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/6720/4480/pexels-photo-5978510.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/4504/3217/pexels-photo-29378239.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/4368/6552/pexels-photo-4596836.jpeg
# {'valid': False, 'reasons': ["bad lemma: 'fresh'", "bad token: 'fresh'", "bad lemma: 'refresh'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/pexels-photo-4593893.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/4480/6720/pexels-photo-4593956.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/2789/2789/pexels-photo-3607053.jpeg
# {'valid': False, 'reasons': ["bad lemma: 'shadow'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/pexels-photo-3663308.jpeg
# {'valid': False, 'reasons': ["bad lemma: 'shadow'", "bad token: 'shadow'", "bad lemma: 'wall'", "bad token: 'wall'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/pexels-photo-3198997.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/2334/2918/pexels-photo-1721554.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/2396/3056/pexels-photo-2125600.jpeg
# {'valid': False, 'reasons': ["bad lemma: 'chameleon'", "bad token: 'chameleon'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/pexels-photo-751689.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/5089/7634/pexels-photo-17558564.jpeg
# {'valid': False, 'reasons': ["bad lemma: 'aerial'", "bad token: 'aerial'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/pexels-photo-6942688.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/3000/4500/pexels-photo-7916014.jpeg
# {'valid': False, 'reasons': ["bad lemma: 'photo'", "bad token: 'photo'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/pexels-photo-333634.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/5304/7952/pexels-photo-10039981.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/3339/4837/pexels-photo-8355460.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/8192/5464/pexels-photo-11025190.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/4480/6720/pexels-photo-5978521.jpeg
# {'valid': False, 'reasons': ["bad lemma: 'stone'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/pexels-photo-7354633.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/3776/5664/pexels-photo-4590413.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/2548/4160/pexels-photo-1863129.jpeg
# {'valid': False, 'reasons': ["bad lemma: 'tile'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/pexels-photo-30817478.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/3024/4032/pexels-photo-30591149.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/4000/2667/pexels-photo-7717987.jpeg
# {'valid': False, 'reasons': ["bad lemma: 'photo'", "bad token: 'photo'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/pexels-photo-7718151.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/2667/4000/pexels-photo-7717679.jpeg
# {'valid': False, 'reasons': ["bad lemma: 'woman'", "bad token: 'woman'", "bad lemma: 'pose'", "bad lemma: 'scene'", "bad token: 'scene'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/pexels-photo-7683037.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/5272/3515/pexels-photo-7931235.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/8192/5461/pexels-photo-7292830.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/4000/6000/pexels-photo-6437697.jpeg
# {'valid': False, 'reasons': ["bad lemma: 'shadow'", "bad lemma: 'wall'", "bad token: 'wall'", "bad lemma: 'scene'", "bad token: 'scene'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/pexels-photo-7013116.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/4000/6000/pexels-photo-6913507.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/3738/5607/pexels-photo-9707468.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/2848/4272/pexels-photo-9007602.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/4725/7084/pexels-photo-11025247.jpeg
# {'valid': False, 'reasons': ["bad lemma: 'bird'", "bad token: 'bird'", "bad lemma: 'art'", "bad token: 'art'", "bad lemma: 'interior'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/pexels-photo-11056627.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/1933/3266/pexels-photo-3278689.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/3000/1698/pexels-photo-2524770.jpeg
# {'valid': False, 'reasons': ["bad lemma: 'light'", "bad token: 'light'", "bad lemma: 'window'", "bad token: 'window'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/pexels-photo-2763355.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/4000/6000/pexels-photo-2873477.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/6000/4000/pexels-photo-3875092.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/6000/4000/pexels-photo-3686307.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/3500/2333/pexels-photo-3567683.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/3648/5472/pexels-photo-3576686.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/3867/5800/pexels-photo-4589437.jpeg
# {'valid': False, 'reasons': ["bad lemma: 'rustic'", "bad token: 'rustic'", "bad lemma: 'wooden'", "bad token: 'wooden'", "bad lemma: 'pathway'", "bad token: 'pathway'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/pexels-photo-5607883.jpeg
# {'valid': False, 'reasons': ["bad lemma: 'woman'", "bad token: 'woman'", "bad lemma: 'pose'", "bad lemma: 'scene'", "bad token: 'scene'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/pexels-photo-7683037.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/5272/3515/pexels-photo-7931235.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/4000/6000/pexels-photo-6437697.jpeg
# {'valid': False, 'reasons': ["bad lemma: 'rustic'", "bad token: 'rustic'", "bad lemma: 'wooden'", "bad token: 'wooden'", "bad lemma: 'pathway'", "bad token: 'pathway'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/pexels-photo-5607883.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/3888/2592/pexels-photo-321900.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/3738/5607/pexels-photo-9707468.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/2848/4272/pexels-photo-9007602.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/4000/6000/pexels-photo-12525303.jpeg
# {'valid': False, 'reasons': ["bad lemma: 'bird'", "bad token: 'bird'", "bad lemma: 'art'", "bad token: 'art'", "bad lemma: 'interior'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/pexels-photo-11056627.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/4725/7084/pexels-photo-11025247.jpeg
# {'valid': False, 'reasons': ["bad lemma: 'aerial'", "bad token: 'aerial'", "bad lemma: 'countryside'", "bad token: 'countryside'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/pexels-photo-8332330.jpeg
# {'valid': False, 'reasons': ["bad lemma: 'shadow'", "bad lemma: 'wall'", "bad token: 'wall'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/pexels-photo-22590600.jpeg
# {'valid': False, 'reasons': ["bad lemma: 'fresh'", "bad token: 'fresh'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/pexels-photo-175268.jpeg
# {'valid': False, 'reasons': ["bad lemma: 'fresh'", "bad token: 'fresh'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/pexels-photo-7013614.jpeg
# {'valid': False, 'reasons': ["bad lemma: 'light'", "bad token: 'light'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/pexels-photo-6102296.jpeg
# {'valid': False, 'reasons': ["bad lemma: 'frame'", "bad token: 'frame'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/pexels-photo-6044496.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/2448/3696/pexels-photo-6044497.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/6000/4000/pexels-photo-6072046.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/3064/4592/pexels-photo-6787170.jpeg
# {'valid': False, 'reasons': ["bad lemma: 'artistic'", "bad token: 'artistic'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/pexels-photo-12496894.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/1920/2560/pexels-photo-7738780.png
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/4000/6000/pexels-photo-7506192.jpeg
# {'valid': False, 'reasons': ["bad lemma: 'paper'", "bad token: 'paper'", "bad lemma: 'female'", "bad token: 'female'", "bad lemma: 'figure'", "bad token: 'figure'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/pexels-photo-8879956.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/4709/3144/pexels-photo-9119729.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/2884/5127/pexels-photo-15324429.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/8192/6554/pexels-photo-6390635.jpeg
# {'valid': False, 'reasons': ["bad lemma: 'hand'", "bad token: 'hand'", "bad lemma: 'hold'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/pexels-photo-4652192.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/6208/4139/pexels-photo-4596807.jpeg
# {'valid': False, 'reasons': ["bad lemma: 'illuminate'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/pexels-photo-2524778.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/3024/4032/pexels-photo-3126877.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/3024/4032/pexels-photo-3701637.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/5616/3744/pexels-photo-5667912.jpeg
# {'valid': False, 'reasons': ["bad lemma: 'silhouette'", "bad token: 'silhouette'", "bad lemma: 'hand'", "bad token: 'hand'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/pexels-photo-5607963.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/6016/4000/pexels-photo-446462.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/2624/3936/pexels-photo-19443302.jpeg
# {'valid': False, 'reasons': ["bad lemma: 'artistic'", "bad token: 'artistic'", "bad lemma: 'composition'", "bad token: 'composition'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/pexels-photo-3293038.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/4032/3024/pexels-photo-2926584.jpeg
# {'valid': False, 'reasons': ["bad lemma: 'shadow'", "bad lemma: 'light'", "bad token: 'light'", "bad lemma: 'shadow'", "bad token: 'shadow'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/pexels-photo-3726226.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/3000/4000/pexels-photo-2862041.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/3456/4608/pexels-photo-2299682.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/4373/2762/pexels-photo-1592242.png
# {'valid': False, 'reasons': ["bad lemma: 'light'", "bad token: 'light'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/pexels-photo-2543244.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/2820/3761/pexels-photo-2530583.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/6000/3376/pexels-photo-1821755.png
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/4896/3264/pexels-photo-937800.jpeg
# {'valid': False, 'reasons': ["bad lemma: 'design'", "bad token: 'design'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/pexels-photo-7486871.jpeg
# {'valid': False, 'reasons': ["bad lemma: 'pot'", "bad token: 'pot'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/pexels-photo-7084255.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/6720/4480/pexels-photo-7291741.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/3744/5616/pexels-photo-27745133.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/3456/5184/pexels-photo-25559763.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/3984/2656/pexels-photo-1040911.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/3188/4250/pexels-photo-28984043.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/4480/6720/pexels-photo-4593879.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/6720/4480/pexels-photo-4593881.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/4200/6300/pexels-photo-4622247.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/3264/4928/pexels-photo-5699665.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/6000/4000/pexels-photo-4870578.jpeg
# {'valid': False, 'reasons': ["bad lemma: 'shadow'", "bad lemma: 'wall'", "bad token: 'wall'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/pexels-photo-6127446.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/4000/6000/pexels-photo-8796865.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/5616/3744/pexels-photo-8189093.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/3024/4032/pexels-photo-10473699.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/4000/2667/pexels-photo-7718204.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/4000/2667/pexels-photo-7718259.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/4160/6240/pexels-photo-18631343.jpeg
# {'valid': False, 'reasons': ["bad lemma: 'frog'", "bad token: 'frog'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/pexels-photo-17839938.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/5464/8192/pexels-photo-11025192.jpeg
# {'valid': False, 'reasons': ["bad lemma: 'arrangement'", "bad token: 'arrangement'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/pexels-photo-31647627.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/6000/4000/pexels-photo-1820933.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/3727/5590/pexels-photo-1180376.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/6000/4000/pexels-photo-1229752.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/6000/4000/pexels-photo-1162711.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/6000/4000/pexels-photo-1588009.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/2400/3000/pexels-photo-2766971.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/4480/6720/pexels-photo-19725807.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/2448/3696/pexels-photo-6044495.jpeg
# {'valid': False, 'reasons': ["bad lemma: 'design'", "bad token: 'design'", "bad lemma: 'decor'", "bad token: 'decor'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/pexels-photo-6331049.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/4016/6016/pexels-photo-5563306.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/6000/4000/pexels-photo-17998785.png
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/5304/6630/pexels-photo-18156012.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/4160/5536/pexels-photo-16816334.jpeg
# {'valid': False, 'reasons': ["bad lemma: 'aerial'", "bad token: 'aerial'", "bad lemma: 'road'", "bad token: 'road'", "bad lemma: 'forest'", "bad token: 'forest'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/pexels-photo-22807062.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/2333/3500/pexels-photo-5527565.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/2000/3000/pexels-photo-4744908.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/3845/5768/pexels-photo-4589135.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/3492/5238/pexels-photo-4590528.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/3024/4032/pexels-photo-2590155.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/4160/6240/pexels-photo-3884233.jpeg
# {'valid': False, 'reasons': ["bad lemma: 'forest'", "bad token: 'forest'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/pexels-photo-12035227.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/2670/4000/pexels-photo-7110337.jpeg
# {'valid': False, 'reasons': ["bad lemma: 'forest'", "bad token: 'forest'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/pexels-photo-18631328.jpeg
# {'valid': False, 'reasons': ["bad lemma: 'stylish'", "bad token: 'stylish'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/pexels-photo-7354859.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/5616/3744/pexels-photo-8180466.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/3456/5184/pexels-photo-14627138.jpeg
# {'valid': False, 'reasons': ["bad lemma: 'silhouette'", "bad token: 'silhouette'", "bad lemma: 'light'", "bad token: 'light'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/pexels-photo-12410130.jpeg
# {'valid': False, 'reasons': ["bad lemma: 'artistic'", "bad token: 'artistic'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/pexels-photo-776514.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/6000/4000/pexels-photo-1069767.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/6000/4000/pexels-photo-1029592.jpeg
# {'valid': False, 'reasons': ["bad lemma: 'window'", "bad token: 'window'", "bad lemma: 'urban'", "bad token: 'urban'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/pexels-photo-2530577.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/2998/3998/pexels-photo-3057600.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/3056/4608/pexels-photo-3026579.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/3120/4160/pexels-photo-1686805.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/2402/3002/pexels-photo-1721553.jpeg
# {'valid': False, 'reasons': ["bad lemma: 'perch'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/pexels-photo-3180754.jpeg
# {'valid': False, 'reasons': ["bad lemma: 'aerial'", "bad token: 'aerial'", "bad lemma: 'country'", "bad token: 'country'", "bad lemma: 'road'", "bad token: 'road'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/pexels-photo-3246159.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/4480/6720/pexels-photo-4622771.jpeg
# {'valid': False, 'reasons': ["bad lemma: 'closeup'", "bad token: 'closeup'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/pexels-photo-4516060.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/4000/6000/pexels-photo-3854752.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/3440/4592/pexels-photo-3826821.jpeg
# {'valid': False, 'reasons': ["bad lemma: 'slice'", "bad token: 'sliced'", "bad lemma: 'pineapple'", "bad token: 'pineapple'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/pexels-photo-5678094.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/4160/6240/pexels-photo-5993687.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/3264/4896/pexels-photo-5275009.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/4000/6000/pexels-photo-6437696.jpeg
# {'valid': False, 'reasons': ["bad lemma: 'light'", "bad token: 'light'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/pexels-photo-1100799.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/6000/4000/pexels-photo-1495160.jpeg
# {'valid': False, 'reasons': ["bad lemma: 'structure'", "bad token: 'structure'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/pexels-photo-6127363.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/3000/4500/pexels-photo-7916013.jpeg
# {'valid': False, 'reasons': ["bad lemma: 'light'", "bad token: 'light'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/pexels-photo-8988960.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/6000/4000/pexels-photo-5740932.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/4480/6720/pexels-photo-5319465.jpeg
# {'valid': False, 'reasons': ["bad lemma: 'wall'", "bad token: 'wall'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/pexels-photo-6913588.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/3064/4592/pexels-photo-6787171.jpeg
# {'valid': False, 'reasons': ["bad lemma: 'shadow'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/pexels-photo-6342354.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/4480/6720/pexels-photo-4589185.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/3697/5545/pexels-photo-4593877.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/4480/6720/pexels-photo-4593980.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/4000/6000/pexels-photo-3686882.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/4000/6000/pexels-photo-2882790.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/5760/3840/pexels-photo-1850528.jpeg
# {'valid': False, 'reasons': ["bad lemma: 'hold'", "bad lemma: 'hand'", "bad token: 'hand'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/pexels-photo-1290085.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/3115/4984/pexels-photo-15086646.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/4000/6000/pexels-photo-12316465.jpeg
# {'valid': False, 'reasons': ["bad lemma: 'fresh'", "bad token: 'fresh'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/pexels-photo-15725074.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/4000/6000/pexels-photo-15639757.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/6240/4160/pexels-photo-15885057.jpeg
# {'valid': False, 'reasons': ["bad lemma: 'light'", "bad token: 'light'", "bad lemma: 'artistic'", "bad token: 'artistic'", "bad lemma: 'scene'", "bad token: 'scene'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/pexels-photo-7505927.jpeg
# {'valid': False, 'reasons': ["bad lemma: 'photo'", "bad token: 'photo'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/pexels-photo-7506119.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/2670/4000/pexels-photo-7318112.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/3500/2336/pexels-photo-7002674.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/3500/2336/pexels-photo-7002944.jpeg
# {'valid': False, 'reasons': ["bad lemma: 'artistic'", "bad token: 'artistic'", "bad lemma: 'composition'", "bad token: 'composition'", "bad lemma: 'light'", "bad token: 'light'", "bad lemma: 'shadow'", "bad token: 'shadow'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/pexels-photo-6707627.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/6554/8192/pexels-photo-7024059.jpeg
# {'valid': False, 'reasons': ["bad lemma: 'studio'", "bad token: 'studio'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/pexels-photo-6899811.jpeg
# {'valid': False, 'reasons': ["bad lemma: 'shadow'", "bad token: 'shadow'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/pexels-photo-7119967.jpeg
# {'valid': False, 'reasons': ["bad lemma: 'light'", "bad token: 'light'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/pexels-photo-6390626.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/8192/6554/pexels-photo-6390634.jpeg
# {'valid': False, 'reasons': ["bad lemma: 'fabric'", "bad token: 'fabric'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/pexels-photo-6102299.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/4000/6000/pexels-photo-5779500.jpeg
# {'valid': False, 'reasons': ["bad lemma: 'forest'", "bad token: 'forest'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/pexels-photo-5777103.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/3024/4032/pexels-photo-5459760.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/4480/6720/pexels-photo-5319468.jpeg
# {'valid': False, 'reasons': ["bad lemma: 'fresh'", "bad token: 'fresh'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/pexels-photo-4870774.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/3723/5584/pexels-photo-4870548.jpeg
# {'valid': False, 'reasons': ["bad lemma: 'photo'", "bad token: 'photo'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/pexels-photo-5008676.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/4896/3264/pexels-photo-5275017.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/3356/2397/pexels-photo-29378249.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/6000/4000/palm-leaf-james-palm-tree-53471.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/4096/6144/fern-plant-green-photosynthesis.jpg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/1920/1080/pexels-photo-92733.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/3456/5184/pexels-photo-86543.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/4032/3024/pexels-photo-440318.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/2176/3192/pexels-photo-1039178.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/3125/4688/pexels-photo-1082068.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/4160/2890/pexels-photo-775874.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/1691/2562/pexels-photo-776498.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/5184/3888/pexels-photo-409798.jpeg
# {'valid': False, 'reasons': ["bad lemma: 'photo'", "bad token: 'photo'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/pexels-photo-1100796.jpeg
# {'valid': False, 'reasons': ["bad lemma: 'environment'", "bad token: 'environment'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/pexels-photo-1481145.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/5108/3102/pexels-photo-1405122.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/4752/3168/pexels-photo-1313431.jpeg
# {'valid': False, 'reasons': ["bad lemma: 'artistic'", "bad token: 'artistic'", "bad lemma: 'photo'", "bad token: 'photo'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/pexels-photo-1320987.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/3883/4854/pexels-photo-3800023.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/5184/3456/pexels-photo-3703154.jpeg
# {'valid': False, 'reasons': ["bad lemma: 'light'", "bad token: 'light'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/pexels-photo-3686275.jpeg
# {'valid': True, 'reasons': None}
# ...
# {'valid': False, 'reasons': ["bad lemma: 'fresh'", "bad token: 'fresh'", "bad lemma: 'light'", "bad token: 'light'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/stinging-nettle-green-pus-nettle-nature-40742.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/2750/4125/konik-grasshopper-insect-macro-67614.jpeg
# {'valid': False, 'reasons': ["bad lemma: 'perch'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/delicate-insect-grasshopper-insect-dotted-69980.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/3888/2592/fan-palm-palm-fan-leaf-59995.jpeg
# {'valid': False, 'reasons': ["bad lemma: 'fly'", "bad token: 'fly'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/pexels-photo-107522.jpeg
# {'valid': False, 'reasons': ["bad lemma: 'pineapple'", "bad token: 'pineapple'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/pexels-photo-174658.jpeg
# {'valid': False, 'reasons': ["bad lemma: 'photo'", "bad token: 'photo'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/pexels-photo-52851.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/4208/2525/pexels-photo-50638.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/2272/1704/plumeria-flower-frangipani-plant-63616.jpeg
# {'valid': False, 'reasons': ["bad lemma: 'fresh'", "bad token: 'fresh'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/pexels-photo-210048.jpeg
# {'valid': False, 'reasons': ["bad lemma: 'forest'", "bad token: 'forest'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/pexels-photo-210020.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/3532/2098/mirror-in-the-drop-grass-meadow-mirroring-158556.jpeg
# {'valid': False, 'reasons': ["bad lemma: 'spider'", "bad token: 'spider'", "bad lemma: 'perch'", "bad lemma: 'eye'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/pexels-photo-2799936.jpeg
# {'valid': False, 'reasons': ["bad lemma: 'ladybug'", "bad token: 'ladybug'", "bad lemma: 'perch'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/pexels-photo-2799976.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/5472/3080/pexels-photo-3192471.jpeg
# {'valid': False, 'reasons': ["bad lemma: 'wooden'", "bad token: 'wooden'", "bad lemma: 'bench'", "bad token: 'bench'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/pexels-photo-3267246.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/4024/6048/pexels-photo-3295121.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/5184/3456/pexels-photo-3138621.jpeg
# {'valid': False, 'reasons': ["bad lemma: 'photo'", "bad token: 'photo'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/pexels-photo-2928438.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/2995/3228/pexels-photo-2738249.jpeg
# {'valid': False, 'reasons': ["bad lemma: 'bee'", "bad token: 'bee'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/pexels-photo-2892244.jpeg
# {'valid': False, 'reasons': ["bad lemma: 'beetle'", "bad token: 'beetle'", "bad lemma: 'perch'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/pexels-photo-2869612.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/4011/2614/pexels-photo-2893181.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/3072/2304/pexels-photo-3906084.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/2160/3240/pexels-photo-3926486.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/5184/3456/pexels-photo-3277497.png
# {'valid': False, 'reasons': ["bad lemma: 'insect'", "bad token: 'insect'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/pexels-photo-3049987.jpeg
# {'valid': False, 'reasons': ["bad lemma: 'lake'", "bad token: 'lake'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/pexels-photo-3081752.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/3598/2442/pexels-photo-2823584.jpeg
# {'valid': False, 'reasons': ["bad lemma: 'butterfly'", "bad token: 'butterfly'", "bad lemma: 'perch'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/pexels-photo-3739602.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/3426/2226/pexels-photo-3691258.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/6000/4000/pexels-photo-3443210.jpeg
# {'valid': False, 'reasons': ["bad lemma: 'photo'", "bad token: 'photo'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/pexels-photo-3800026.jpeg
# {'valid': False, 'reasons': ["bad lemma: 'spider'", "bad token: 'spider'", "bad lemma: 'perch'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/pexels-photo-3757601.jpeg
# {'valid': False, 'reasons': ["bad lemma: 'spider'", "bad token: 'spider'", "bad lemma: 'perch'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/pexels-photo-3835883.jpeg
# {'valid': False, 'reasons': ["bad lemma: 'insect'", "bad token: 'insect'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/pexels-photo-2807498.jpeg
# {'valid': False, 'reasons': ["bad lemma: 'perch'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/pexels-photo-2851617.jpeg
# {'valid': False, 'reasons': ["bad lemma: 'butterfly'", "bad token: 'butterfly'"]}
# [REJECTED] Saved to: /mnt/mls/images/rejected/young sprout macro/pexels-photo-2657655.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/6000/4000/pexels-photo-2156979.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/4000/6000/pexels-photo-1568612.jpeg
# {'valid': True, 'reasons': None}
# Saved to: /mnt/mls/images/clean/young sprout macro/3648/5472/pexels-photo-1779189.jpeg
# {'valid': False, 'reasons': ["bad lemma: 'young'", "bad token: 'young'", "bad lemma: 'woman'", "bad token: 'woman'", "bad lemma: 'hold'"]}
# ---------------------------------------------------------------------------
# RemoteDisconnected                        Traceback (most recent call last)
# File /mnt/mls/venv/lib/python3.12/site-packages/urllib3/connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#
# File /mnt/mls/venv/lib/python3.12/site-packages/urllib3/connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#
# File /mnt/mls/venv/lib/python3.12/site-packages/urllib3/connection.py:516, in HTTPConnection.getresponse(self)
#     515 # Get the response from http.client.HTTPConnection
# --> 516 httplib_response = super().getresponse()
#     518 try:
#
# File /usr/lib/python3.12/http/client.py:1428, in HTTPConnection.getresponse(self)
#    1427 try:
# -> 1428     response.begin()
#    1429 except ConnectionError:
#
# File /usr/lib/python3.12/http/client.py:331, in HTTPResponse.begin(self)
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#
# File /usr/lib/python3.12/http/client.py:300, in HTTPResponse._read_status(self)
#     297 if not line:
#     298     # Presumably, the server closed the connection before
#     299     # sending a valid response.
# --> 300     raise RemoteDisconnected("Remote end closed connection without"
#     301                              " response")
#     302 try:
#
# RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# File /mnt/mls/venv/lib/python3.12/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#
# File /mnt/mls/venv/lib/python3.12/site-packages/urllib3/connectionpool.py:841, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     839     new_e = ProtocolError("Connection aborted.", new_e)
# --> 841 retries = retries.increment(
#     842     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     843 )
#     844 retries.sleep()
#
# File /mnt/mls/venv/lib/python3.12/site-packages/urllib3/util/retry.py:474, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     473 if read is False or method is None or not self._is_method_retryable(method):
# --> 474     raise reraise(type(error), error, _stacktrace)
#     475 elif read is not None:
#
# File /mnt/mls/venv/lib/python3.12/site-packages/urllib3/util/util.py:38, in reraise(tp, value, tb)
#      37 if value.__traceback__ is not tb:
# ---> 38     raise value.with_traceback(tb)
#      39 raise value
#
# File /mnt/mls/venv/lib/python3.12/site-packages/urllib3/connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#
# File /mnt/mls/venv/lib/python3.12/site-packages/urllib3/connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#
# File /mnt/mls/venv/lib/python3.12/site-packages/urllib3/connection.py:516, in HTTPConnection.getresponse(self)
#     515 # Get the response from http.client.HTTPConnection
# --> 516 httplib_response = super().getresponse()
#     518 try:
#
# File /usr/lib/python3.12/http/client.py:1428, in HTTPConnection.getresponse(self)
#    1427 try:
# -> 1428     response.begin()
#    1429 except ConnectionError:
#
# File /usr/lib/python3.12/http/client.py:331, in HTTPResponse.begin(self)
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#
# File /usr/lib/python3.12/http/client.py:300, in HTTPResponse._read_status(self)
#     297 if not line:
#     298     # Presumably, the server closed the connection before
#     299     # sending a valid response.
# --> 300     raise RemoteDisconnected("Remote end closed connection without"
#     301                              " response")
#     302 try:
#
# ProtocolError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# Cell In[15], line 11
#       9 if not result['valid']:
#      10     rejected_count += 1
# ---> 11     save_image_to_rejects(
#      12         url=row['original'],
#      13         base_dir=images_dir,
#      14         label=query_label,
#      15         alt_text=row['alt'],
#      16         reasons=result['reasons']
#      17     )
#      19 else:
#      20     clean_count += 1
#
# Cell In[14], line 4, in save_image_to_rejects(url, base_dir, label, alt_text, reasons)
#       1 def save_image_to_rejects(url: str, base_dir: str | None = None, label: str | None = None,
#       2                           alt_text: str = '', reasons: list | None = None) -> None:
#       3     filename = urlparse(url).path.split("/")[-1]
# ----> 4     response = requests.get(url, verify=certifi.where())
#       5     image = Image.open(BytesIO(response.content)).convert("RGB")
#       7     folder_path = f'{base_dir}/rejected/{label}'
#
# File /mnt/mls/venv/lib/python3.12/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)     70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File /mnt/mls/venv/lib/python3.12/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File /mnt/mls/venv/lib/python3.12/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File /mnt/mls/venv/lib/python3.12/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File /mnt/mls/venv/lib/python3.12/site-packages/requests/adapters.py:682, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#    (...)    678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
# --> 682     raise ConnectionError(err, request=request)
#     684 except MaxRetryError as e:
#     685     if isinstance(e.reason, ConnectTimeoutError):
#     686         # TODO: Remove this in 3.0.0: see #2811
#
# ConnectionError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
